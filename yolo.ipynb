WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/8fe618c9-8ea6-4f82-b634-cfebc8a47122_0180.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     6.8275      5.2883]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/8fe618c9-8ea6-4f82-b634-cfebc8a47122_0186.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     6.8271       5.288]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/9ca144df-4438-40ae-a7e3-227ba1885844_0032.jpg: ignoring corrupt image/label: negative label values [  -0.077193]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/a732dc3d-ff5c-41ef-8a56-afcbcf4fd7f6_0017.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0204]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/a732dc3d-ff5c-41ef-8a56-afcbcf4fd7f6_0041.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0733]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/c6b38078-47e9-41e4-913a-c082736fb1cf_0190.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0871]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/cb65a1e9-c01f-49ce-8e46-0f791aae4bf9_0034.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2002]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/d1d539c2-8321-45d9-868a-fd8544e0ce01_0005.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0218]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/d1d539c2-8321-45d9-868a-fd8544e0ce01_0011.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3908      6.0014]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/d1d539c2-8321-45d9-868a-fd8544e0ce01_0026.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.4856]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/d1d539c2-8321-45d9-868a-fd8544e0ce01_0036.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.5362]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/dd49d264-aecf-4d23-92c1-adf35a8ab29b_0087.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3094]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/dd49d264-aecf-4d23-92c1-adf35a8ab29b_0098.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3094]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/dd49d264-aecf-4d23-92c1-adf35a8ab29b_0106.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.3096]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/dd49d264-aecf-4d23-92c1-adf35a8ab29b_0107.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.309]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/eb46684b-f8c9-455e-80ff-1e168d7d2f7c_0008.jpg: ignoring corrupt image/label: negative label values [  -0.032602]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/eb46684b-f8c9-455e-80ff-1e168d7d2f7c_0009.jpg: ignoring corrupt image/label: negative label values [  -0.045332]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/eb46684b-f8c9-455e-80ff-1e168d7d2f7c_0014.jpg: ignoring corrupt image/label: negative label values [  -0.076463]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/eb46684b-f8c9-455e-80ff-1e168d7d2f7c_0023.jpg: ignoring corrupt image/label: negative label values [  -0.076575]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/eb46684b-f8c9-455e-80ff-1e168d7d2f7c_0039.jpg: ignoring corrupt image/label: negative label values [  -0.076575]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/f075920b-5e7a-4c75-8ce8-3368d5f4254b_0020.jpg: ignoring corrupt image/label: negative label values [  -0.038781]
# val: WARNING ⚠️ /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/images/val/f171f50d-4781-41b6-bec1-3e7a15e596dc_0065.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.348      3.5397       1.861]
# val: New cache created: /Users/yuxuanhe/Desktop/PerceptionFinalProj_export/datasets/datasets/labels/val.cache
# Plotting labels to runs/detect/train3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3         0G      1.635      5.212      1.266         30        640:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 results = model.train(data='data.yaml', epochs=3)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/engine/model.py:370, in YOLO.train(self, **kwargs)
#     368     self.model = self.trainer.model
#     369 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 370 self.trainer.train()
#     371 # Update model and cfg after training
#     372 if RANK in (-1, 0):
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/engine/trainer.py:191, in BaseTrainer.train(self)
#     189         ddp_cleanup(self, str(file))
#     190 else:
# --> 191     self._do_train(world_size)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/engine/trainer.py:323, in BaseTrainer._do_train(self, world_size)
#     321 with torch.cuda.amp.autocast(self.amp):
#     322     batch = self.preprocess_batch(batch)
# --> 323     preds = self.model(batch['img'])
#     324     self.loss, self.loss_items = self.criterion(preds, batch)
#     325     if RANK != -1:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:205, in DetectionModel.forward(self, x, augment, profile, visualize)
#     203 if augment:
#     204     return self._forward_augment(x)  # augmented inference, None
# --> 205 return self._forward_once(x, profile, visualize)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/tasks.py:59, in BaseModel._forward_once(self, x, profile, visualize)
#      57 if profile:
#      58     self._profile_one_layer(m, x, dt)
# ---> 59 x = m(x)  # run
#      60 y.append(x if m.i in self.save else None)  # save output
#      61 if visualize:
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/modules.py:471, in Detect.forward(self, x)
#     469 shape = x[0].shape  # BCHW
#     470 for i in range(self.nl):
# --> 471     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#     472 if self.training:
#     473     return x
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/nn/modules.py:36, in Conv.forward(self, x)
#      34 def forward(self, x):
#      35     """Apply convolution, batch normalization and activation to input tensor."""
# ---> 36     return self.act(self.bn(self.conv(x)))
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
from glob import glob
from collections import defaultdict
from matplotlib import pyplot as plt

# %%
files = glob('test/*/*_image.jpg')

# %%
inputs = files

# %%
res = model(inputs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 res = model(inputs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/engine/model.py:111, in YOLO.__call__(self, source, stream, **kwargs)
#     109 def __call__(self, source=None, stream=False, **kwargs):
#     110     """Calls the 'predict' function with given arguments to perform object detection."""
# --> 111     return self.predict(source, stream, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/engine/model.py:252, in YOLO.predict(self, source, stream, **kwargs)
#     250 else:  # only update args if predictor is already setup
#     251     self.predictor.args = get_cfg(self.predictor.args, overrides)
# --> 252 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/engine/predictor.py:176, in BasePredictor.__call__(self, source, model, stream)
#     174     return self.stream_inference(source, model)
#     175 else:
# --> 176     return list(self.stream_inference(source, model))
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/engine/predictor.py:207, in BasePredictor.stream_inference(self, source, model)
#     205     self.setup_model(model)
#     206 # Setup source every time predict is called
# --> 207 self.setup_source(source if source is not None else self.args.source)
#     209 # Check if save_dir/ label file exists
#     210 if self.args.save or self.args.save_txt:
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/engine/predictor.py:189, in BasePredictor.setup_source(self, source)
#     186 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#     187 self.transforms = getattr(self.model.model, 'transforms', classify_transforms(
#     188     self.imgsz[0])) if self.args.task == 'classify' else None
# --> 189 self.dataset = load_inference_source(source=source, imgsz=self.imgsz, vid_stride=self.args.vid_stride)
#     190 self.source_type = self.dataset.source_type
#     191 if not getattr(self, 'stream', True) and (self.dataset.mode == 'stream' or  # streams
#     192                                           len(self.dataset) > 1000 or  # images
#     193                                           any(getattr(self.dataset, 'video_flag', [False]))):  # videos
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/data/build.py:163, in load_inference_source(source, imgsz, vid_stride)
#     161     dataset = LoadScreenshots(source, imgsz=imgsz)
#     162 elif from_img:
# --> 163     dataset = LoadPilAndNumpy(source, imgsz=imgsz)
#     164 else:
#     165     dataset = LoadImages(source, imgsz=imgsz, vid_stride=vid_stride)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py:263, in LoadPilAndNumpy.__init__(self, im0, imgsz)
#     261     im0 = [im0]
#     262 self.paths = [getattr(im, 'filename', f'image{i}.jpg') for i, im in enumerate(im0)]
# --> 263 self.im0 = [self._single_check(im) for im in im0]
#     264 self.imgsz = imgsz
#     265 self.mode = 'image'
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py:263, in <listcomp>(.0)
#     261     im0 = [im0]
#     262 self.paths = [getattr(im, 'filename', f'image{i}.jpg') for i, im in enumerate(im0)]
# --> 263 self.im0 = [self._single_check(im) for im in im0]
#     264 self.imgsz = imgsz
#     265 self.mode = 'image'
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py:276, in LoadPilAndNumpy._single_check(im)
#     274     if im.mode != 'RGB':
#     275         im = im.convert('RGB')
# --> 276     im = np.asarray(im)[:, :, ::-1]
#     277     im = np.ascontiguousarray(im)  # contiguous
#     278 return im
#
# File ~/Library/Python/3.9/lib/python/site-packages/PIL/Image.py:696, in Image.__array_interface__(self)
#     694         new["data"] = self.tobytes("raw", "L")
#     695     else:
# --> 696         new["data"] = self.tobytes()
#     697 except Exception as e:
#     698     if not isinstance(e, (MemoryError, RecursionError)):
#
# File ~/Library/Python/3.9/lib/python/site-packages/PIL/Image.py:767, in Image.tobytes(self, encoder_name, *args)
#     765 output = []
#     766 while True:
# --> 767     bytes_consumed, errcode, data = e.encode(bufsize)
#     768     output.append(data)
#     769     if errcode:
#
# KeyboardInterrupt:

# %%
res = model([files[0]])
# Out:
# 0: 352x640 (no detections), 122.7ms
# Speed: 22.0ms preprocess, 122.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
for i in range(10):
    print(model([files[i]]))
# Out:
# 0: 352x640 (no detections), 57.8ms
# Speed: 3.7ms preprocess, 57.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 (no detections), 53.8ms
# Speed: 2.8ms preprocess, 53.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[234, 203, 172],
#         [234, 203, 172],
#         [234, 203, 172],
#         ...,
#         [235, 208, 187],
#         [235, 208, 187],
#         [235, 208, 187]],
#
#        [[234, 203, 172],
#         [234, 203, 172],
#         [234, 203, 172],
#         ...,
#         [235, 208, 187],
#         [235, 208, 187],
#         [235, 208, 187]],
#
#        [[234, 203, 172],
#         [234, 203, 172],
#         [234, 203, 172],
#         ...,
#         [235, 208, 187],
#         [235, 208, 187],
#         [235, 208, 187]],
#
#        ...,
#
#        [[ 83,  75,  76],
#         [ 86,  81,  80],
#         [ 93,  89,  84],
#         ...,
#         [ 54,  45,  42],
#         [ 54,  45,  42],
#         [ 54,  45,  42]],
#
#        [[ 89,  82,  73],
#         [ 90,  86,  75],
#         [ 96,  92,  81],
#         ...,
#         [ 53,  44,  40],
#         [ 55,  46,  43],
#         [ 55,  46,  43]],
#
#        [[ 89,  84,  69],
#         [ 93,  88,  73],
#         [ 96,  93,  78],
#         ...,
#         [ 52,  43,  39],
#         [ 55,  46,  43],
#         [ 55,  46,  43]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0006_image.jpg'
# probs: None
# speed: {'preprocess': 3.665924072265625, 'inference': 57.823896408081055, 'postprocess': 0.3209114074707031}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[230, 201, 170],
#         [230, 201, 170],
#         [230, 201, 170],
#         ...,
#         [234, 208, 191],
#         [237, 209, 192],
#         [239, 209, 190]],
#
#        [[230, 201, 170],
#         [230, 201, 170],
#         [230, 201, 170],
#         ...,
#         [234, 209, 189],
#         [230, 203, 183],
#         [231, 204, 183]],
#
#        [[230, 201, 170],
#         [230, 201, 170],
#         [230, 201, 170],
#         ...,
#         [237, 209, 185],
#         [235, 209, 185],
#         [232, 208, 184]],
#
#        ...,
#
#        [[152, 156, 157],
#         [161, 166, 165],
#         [172, 177, 175],
#         ...,
#         [123, 141, 140],
#         [122, 139, 135],
#         [122, 140, 133]],
#
#        [[171, 176, 167],
#         [174, 182, 171],
#         [179, 187, 176],
#         ...,
#         [117, 133, 146],
#         [117, 132, 141],
#         [117, 133, 140]],
#
#        [[172, 179, 164],
#         [175, 182, 167],
#         [174, 184, 167],
#         ...,
#         [114, 128, 150],
#         [126, 138, 156],
#         [126, 139, 155]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0012_image.jpg'
# probs: None
# speed: {'preprocess': 2.7971267700195312, 'inference': 53.809165954589844, 'postprocess': 0.35309791564941406}]
# 0: 352x640 (no detections), 50.6ms
# Speed: 2.8ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 (no detections), 55.9ms
# Speed: 2.7ms preprocess, 55.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[235, 211, 193],
#         [235, 211, 193],
#         [235, 211, 193],
#         ...,
#         [235, 212, 196],
#         [235, 212, 196],
#         [235, 212, 196]],
#
#        [[235, 211, 193],
#         [235, 211, 193],
#         [235, 211, 193],
#         ...,
#         [235, 212, 196],
#         [235, 212, 196],
#         [235, 212, 196]],
#
#        [[235, 211, 193],
#         [235, 211, 193],
#         [235, 211, 193],
#         ...,
#         [235, 212, 196],
#         [235, 212, 196],
#         [235, 212, 196]],
#
#        ...,
#
#        [[135, 130, 115],
#         [139, 134, 119],
#         [146, 138, 125],
#         ...,
#         [147, 148, 138],
#         [135, 134, 124],
#         [133, 134, 124]],
#
#        [[143, 135, 122],
#         [146, 138, 125],
#         [151, 142, 132],
#         ...,
#         [151, 149, 141],
#         [144, 142, 132],
#         [143, 142, 132]],
#
#        [[146, 138, 125],
#         [149, 141, 128],
#         [153, 144, 134],
#         ...,
#         [148, 145, 137],
#         [149, 146, 138],
#         [150, 148, 138]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0068_image.jpg'
# probs: None
# speed: {'preprocess': 2.7790069580078125, 'inference': 50.582170486450195, 'postprocess': 0.44608116149902344}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[229, 198, 167],
#         [229, 198, 167],
#         [229, 198, 167],
#         ...,
#         [142, 125, 152],
#         [200, 173, 182],
#         [208, 177, 174]],
#
#        [[229, 198, 167],
#         [229, 198, 167],
#         [229, 198, 167],
#         ...,
#         [117, 103, 151],
#         [211, 187, 221],
#         [218, 192, 216]],
#
#        [[229, 198, 167],
#         [229, 198, 167],
#         [229, 198, 167],
#         ...,
#         [ 73,  64, 155],
#         [111,  95, 179],
#         [117,  98, 179]],
#
#        ...,
#
#        [[ 73,  74,  70],
#         [ 74,  75,  71],
#         [ 74,  75,  71],
#         ...,
#         [103, 112, 122],
#         [104, 111, 126],
#         [106, 113, 128]],
#
#        [[ 71,  73,  67],
#         [ 71,  73,  67],
#         [ 71,  72,  68],
#         ...,
#         [101, 108, 117],
#         [105, 113, 126],
#         [106, 114, 127]],
#
#        [[ 70,  72,  66],
#         [ 70,  72,  66],
#         [ 69,  70,  66],
#         ...,
#         [ 96, 104, 111],
#         [102, 111, 121],
#         [103, 111, 124]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0033_image.jpg'
# probs: None
# speed: {'preprocess': 2.711057662963867, 'inference': 55.92703819274902, 'postprocess': 0.31685829162597656}]
# 0: 352x640 1 Service, 54.4ms
# Speed: 2.6ms preprocess, 54.4ms inference, 10.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 1 Service, 54.9ms
# Speed: 3.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[235, 215, 198],
#         [235, 215, 198],
#         [235, 215, 198],
#         ...,
#         [235, 211, 191],
#         [235, 211, 191],
#         [235, 211, 191]],
#
#        [[235, 215, 198],
#         [235, 215, 198],
#         [235, 215, 198],
#         ...,
#         [235, 211, 191],
#         [235, 211, 191],
#         [235, 211, 191]],
#
#        [[235, 215, 198],
#         [235, 215, 198],
#         [235, 215, 198],
#         ...,
#         [235, 211, 191],
#         [235, 211, 191],
#         [235, 211, 191]],
#
#        ...,
#
#        [[ 93,  97,  91],
#         [ 91,  97,  92],
#         [ 95, 100,  98],
#         ...,
#         [131, 156, 176],
#         [133, 157, 175],
#         [133, 157, 175]],
#
#        [[ 98, 100,  94],
#         [ 98, 102,  96],
#         [103, 110, 103],
#         ...,
#         [134, 158, 176],
#         [133, 157, 175],
#         [133, 157, 175]],
#
#        [[100, 102,  96],
#         [100, 104,  98],
#         [110, 115, 106],
#         ...,
#         [135, 159, 177],
#         [133, 157, 175],
#         [133, 157, 175]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0080_image.jpg'
# probs: None
# speed: {'preprocess': 2.5548934936523438, 'inference': 54.413795471191406, 'postprocess': 10.780811309814453}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[227, 196, 171],
#         [227, 196, 171],
#         [227, 196, 171],
#         ...,
#         [228, 209, 196],
#         [228, 209, 196],
#         [228, 209, 196]],
#
#        [[227, 196, 171],
#         [227, 196, 171],
#         [227, 196, 171],
#         ...,
#         [228, 209, 196],
#         [228, 209, 196],
#         [228, 209, 196]],
#
#        [[227, 196, 171],
#         [227, 196, 171],
#         [227, 196, 171],
#         ...,
#         [228, 209, 196],
#         [228, 209, 196],
#         [228, 209, 196]],
#
#        ...,
#
#        [[139, 151, 161],
#         [139, 151, 161],
#         [139, 151, 157],
#         ...,
#         [118, 134, 150],
#         [130, 146, 169],
#         [133, 148, 174]],
#
#        [[135, 146, 154],
#         [132, 143, 151],
#         [130, 139, 148],
#         ...,
#         [121, 136, 155],
#         [128, 142, 170],
#         [130, 145, 177]],
#
#        [[140, 152, 158],
#         [134, 146, 152],
#         [130, 139, 148],
#         ...,
#         [126, 143, 164],
#         [125, 138, 170],
#         [126, 140, 176]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0049_image.jpg'
# probs: None
# speed: {'preprocess': 3.0078887939453125, 'inference': 54.898977279663086, 'postprocess': 1.0230541229248047}]
# 0: 352x640 (no detections), 51.1ms
# Speed: 2.6ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 1 Service, 49.8ms
# Speed: 2.8ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 1 Service, 50.8ms
# Speed: 2.6ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[231, 200, 167],
#         [231, 200, 167],
#         [231, 200, 167],
#         ...,
#         [232, 208, 190],
#         [232, 208, 188],
#         [232, 208, 188]],
#
#        [[231, 200, 167],
#         [231, 200, 167],
#         [231, 200, 167],
#         ...,
#         [232, 208, 188],
#         [232, 208, 188],
#         [232, 208, 188]],
#
#        [[231, 200, 167],
#         [231, 200, 167],
#         [231, 200, 167],
#         ...,
#         [233, 209, 187],
#         [233, 209, 187],
#         [233, 209, 187]],
#
#        ...,
#
#        [[121, 124, 129],
#         [119, 122, 126],
#         [122, 126, 127],
#         ...,
#         [109, 119, 126],
#         [111, 122, 126],
#         [111, 123, 125]],
#
#        [[130, 131, 135],
#         [126, 128, 129],
#         [123, 127, 128],
#         ...,
#         [108, 119, 123],
#         [109, 121, 121],
#         [109, 122, 120]],
#
#        [[128, 130, 131],
#         [124, 126, 127],
#         [119, 123, 124],
#         ...,
#         [101, 113, 115],
#         [104, 117, 115],
#         [104, 118, 114]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0027_image.jpg'
# probs: None
# speed: {'preprocess': 2.590179443359375, 'inference': 51.14388465881348, 'postprocess': 0.34308433532714844}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[237, 217, 200],
#         [237, 217, 200],
#         [237, 217, 200],
#         ...,
#         [238, 214, 196],
#         [238, 214, 196],
#         [238, 214, 196]],
#
#        [[237, 217, 200],
#         [237, 217, 200],
#         [237, 217, 200],
#         ...,
#         [238, 214, 196],
#         [238, 214, 196],
#         [238, 214, 196]],
#
#        [[237, 217, 200],
#         [237, 217, 200],
#         [237, 217, 200],
#         ...,
#         [238, 214, 196],
#         [238, 214, 196],
#         [238, 214, 196]],
#
#        ...,
#
#        [[108, 107, 111],
#         [101, 100, 104],
#         [ 98,  95,  97],
#         ...,
#         [107, 108,  99],
#         [114, 117, 108],
#         [115, 118, 109]],
#
#        [[106, 103, 105],
#         [ 99,  96,  98],
#         [ 94,  90,  95],
#         ...,
#         [ 90,  91,  82],
#         [ 95,  96,  87],
#         [ 95,  96,  86]],
#
#        [[103, 100, 102],
#         [ 96,  93,  95],
#         [ 92,  88,  93],
#         ...,
#         [ 81,  82,  73],
#         [ 75,  76,  66],
#         [ 75,  76,  66]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0071_image.jpg'
# probs: None
# speed: {'preprocess': 2.7971267700195312, 'inference': 49.848079681396484, 'postprocess': 0.6349086761474609}]
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[229, 205, 185],
#         [229, 205, 185],
#         [229, 205, 185],
#         ...,
#         [233, 208, 192],
#         [233, 208, 192],
#         [233, 208, 192]],
#
#        [[229, 205, 185],
#         [229, 205, 185],
#         [229, 205, 185],
#         ...,
#         [233, 208, 192],
#         [233, 208, 192],
#         [233, 208, 192]],
#
#        [[230, 206, 186],
#         [230, 206, 186],
#         [230, 206, 186],
#         ...,
#         [233, 208, 192],
#         [233, 208, 192],
#         [233, 208, 192]],
#
#        ...,
#
#        [[135, 144, 147],
#         [127, 137, 144],
#         [125, 131, 150],
#         ...,
#         [183, 197, 196],
#         [181, 195, 194],
#         [181, 195, 194]],
#
#        [[136, 144, 144],
#         [131, 140, 144],
#         [133, 139, 150],
#         ...,
#         [191, 203, 205],
#         [186, 198, 200],
#         [186, 198, 200]],
#
#        [[137, 145, 145],
#         [134, 141, 144],
#         [135, 143, 150],
#         ...,
#         [193, 205, 207],
#         [189, 201, 203],
#         [189, 201, 203]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0065_image.jpg'
# probs: None
# speed: {'preprocess': 2.6488304138183594, 'inference': 50.79007148742676, 'postprocess': 0.6439685821533203}]
# 0: 352x640 1 Service, 59.8ms
# Speed: 3.2ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Unknown', 1: 'Compacts', 2: 'Sedans', 3: 'SUVs', 4: 'Coupes', 5: 'Muscle', 6: 'SportsClassics', 7: 'Sports', 8: 'Super', 9: 'Motorcycles', 10: 'OffRoad', 11: 'Industrial', 12: 'Utility', 13: 'Vans', 14: 'Cycles', 15: 'Boats', 16: 'Helicopters', 17: 'Planes', 18: 'Service', 19: 'Emergency', 20: 'Military', 21: 'Commercial', 22: 'Trains'}
# orig_img: array([[[227, 196, 173],
#         [227, 196, 173],
#         [227, 196, 173],
#         ...,
#         [225, 208, 199],
#         [223, 208, 199],
#         [223, 208, 199]],
#
#        [[227, 196, 173],
#         [227, 196, 173],
#         [227, 196, 173],
#         ...,
#         [225, 208, 199],
#         [223, 208, 199],
#         [223, 208, 199]],
#
#        [[227, 196, 173],
#         [227, 196, 173],
#         [227, 196, 173],
#         ...,
#         [225, 209, 197],
#         [225, 209, 197],
#         [225, 209, 197]],
#
#        ...,
#
#        [[129, 146, 155],
#         [138, 155, 158],
#         [149, 169, 157],
#         ...,
#         [141, 152, 149],
#         [138, 147, 156],
#         [139, 148, 162]],
#
#        [[129, 148, 153],
#         [138, 158, 153],
#         [147, 171, 147],
#         ...,
#         [141, 154, 140],
#         [129, 140, 144],
#         [131, 140, 153]],
#
#        [[121, 140, 143],
#         [128, 149, 141],
#         [136, 162, 132],
#         ...,
#         [143, 157, 139],
#         [118, 130, 132],
#         [120, 129, 142]]], dtype=uint8)
# orig_shape: (1052, 1914)
# path: 'test/e024982a-233f-45b4-a6ec-505f5b0c2649/0044_image.jpg'
# probs: None
# speed: {'preprocess': 3.245115280151367, 'inference': 59.81802940368652, 'postprocess': 0.8580684661865234}]

# %%
from gluoncv import model_zoo, data, utils
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 from gluoncv import model_zoo, data, utils
#       2 from matplotlib import pyplot as plt
#
# File ~/Library/Python/3.9/lib/python/site-packages/gluoncv/__init__.py:27
#      24     pass
#      26 try:
# ---> 27     _require_pytorch_version('1.4.0', '2.0.0')
#      28     _found_pytorch = True
#      29 except ImportError:
#
# File ~/Library/Python/3.9/lib/python/site-packages/gluoncv/check.py:36, in _require_pytorch_version(torch_version, max_torch_version)
#      32         version_str = '>={},<{}'.format(torch_version, max_torch_version)
#      33         msg = (
#      34             "Legacy torch=={0} detected, some modules may not work properly. "
#      35             "torch{1} is required. You can use pip or conda to upgrade".format(torch.__version__, version_str))
# ---> 36         raise RuntimeError(msg)
#      37 except ImportError as ex:
#      38     raise ImportError(
#      39         "Unable to import dependency pytorch. Please use pip or conda to install.") from ex
#
# RuntimeError: Legacy torch==2.0.0 detected, some modules may not work properly. torch>=1.4.0,<2.0.0 is required. You can use pip or conda to upgrade
